# %%
import pandas as pd

# %%
simpsons = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes')

# %%
len(simpsons)
# Out:
# 15

# %%
simpsons[1]
# Out:
#                    Title      Directed by  \
# 0    The Longest Daycare  David Silverman
# 1  Playdate with Destiny  David Silverman
#
#                                           Written by Original release date
# 0  James L. Brooks, Matt Groening, Al Jean, David...         July 13, 2012
# 1  Al Jean, Tom Gammill, Max Pross, James L. Broo...         March 6, 2020

# %% [markdown]
# # Website th scrape
# https://www.football-data.co.uk/data.php

# %%
# read 1 csv file from the website
data_pl_25  = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')

# %%
data_pl_25
# Out:
#     Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00   Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30      Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00      Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00      Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00    Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...          ...          ...   ...   ...  ..   ...
# 284  E0  15/03/2025  15:00  Southampton       Wolves     1     2   A     0
# 285  E0  15/03/2025  17:30  Bournemouth    Brentford     1     2   A     1
# 286  E0  16/03/2025  13:30      Arsenal      Chelsea     1     0   H     1
# 287  E0  16/03/2025  13:30       Fulham    Tottenham     2     0   H     0
# 288  E0  16/03/2025  19:00    Leicester   Man United     0     3   A     0
#
#      HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0       0  ...     1.86     2.07   1.83   2.11     1.88     2.11     1.82
# 1       0  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99
# 2       0  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99
# 3       1  ...     1.87     2.06   1.86   2.07     1.92     2.10     1.83
# 4       0  ...     1.87     2.06   1.88   2.06     1.89     2.10     1.82
# ..    ...  ...      ...      ...    ...    ...      ...      ...      ...
# 284     1  ...     1.86     2.07   1.85   2.08     1.89     2.08     1.83
# 285     1  ...     1.96     1.97   1.96   1.96     1.99     1.97     1.94
# 286     0  ...     1.95     1.95   1.96   1.96     1.97     1.97     1.94
# 287     0  ...     1.84     2.06   1.85   2.08     1.86     2.09     1.84
# 288     1  ...     1.78     2.03   1.85   2.08     1.88     2.11     1.82
#
#      AvgCAHA  BFECAHH  BFECAHA
# 0       2.05     1.90     2.08
# 1       1.88     2.04     1.93
# 2       1.87     2.02     1.96
# 3       2.04     1.88     2.11
# 4       2.05     1.89     2.10
# ..       ...      ...      ...
# 284     2.04     1.89     2.10
# 285     1.92     2.00     1.98
# 286     1.92     1.96     2.02
# 287     2.02     1.90     2.10
# 288     2.05     1.87     2.13
#
# [289 rows x 120 columns]
